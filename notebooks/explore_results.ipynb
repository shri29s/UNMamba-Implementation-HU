# %%
import numpy as np

# %%
history = np.load("../unmixing_results.npz", allow_pickle=True)

# %%
history.keys()
# Out:
# KeysView(NpzFile '../unmixing_results.npz' with keys: epochs, losses, M_history, E_history, metrics)

# %%
history["losses"]
# Out:
# array([0.5599032 , 0.49936274, 0.43986177, 0.38583186, 0.33517793,
#        0.29206282, 0.25661293, 0.22667314, 0.20005006, 0.18007804,
#        0.16020496, 0.14295049, 0.3000069 , 0.26887304, 0.11561737,
#        0.24706285, 0.1056084 , 0.10072993, 0.09395082, 0.09424698,
#        0.08991134, 0.08476931, 0.08310799, 0.08064234, 0.08494227,
#        0.07868977, 0.33659029, 0.07528383, 0.07411103, 0.07382343,
#        0.07631914, 0.07362088, 0.07350483, 0.07234716, 0.07273977,
#        0.07147142, 0.1432651 , 0.07009636, 0.0698873 , 0.06948359,
#        0.07030212, 0.14225177, 0.14536874, 0.06973224, 0.33027333,
#        0.06998952, 0.14025608, 0.06907423, 0.06849808, 0.14140955,
#        0.06789821, 0.06881473, 0.06783599])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history["epochs"], history["losses"])
plt.title("Loss vs Epoch")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
for i, map in enumerate(history["M_history"][-1:]):
    map = map.squeeze()
    plt.figure(figsize=(9, 9))
    
    for i in range(len(map)):
        plt.subplot(2, 2, i + 1)
        plt.imshow(map[i], cmap="jet")
    
    plt.savefig(f"../results/M{i}.png")

# %%
for i, endmems in enumerate(history["E_history"][-1:]):
    plt.figure(figsize=(18, 9))
    
    for i in range(len(map)):
        plt.subplot(2, 2, i + 1)
        plt.plot(endmems[i])
    
    plt.savefig(f"../results/E{i}.png")

# %%
metrics = history["metrics"].item()

# %%
for k, v in metrics.items():
    print(k, v)
# Out:
# rec_rmse 0.049088518880844964
# sad_per_em [0.07388441 0.05484394 0.1230813  0.08471975]
# mean_sad 0.08413235044436523
# sid_per_em [0.01749927 0.03492325 0.02689398 0.00852672]
# mean_sid 0.02196080522957125
# ab_rmse_per_em [0.07719653 0.06875275 0.13255944 0.13419462]
# mean_ab_rmse 0.10317583273811151
