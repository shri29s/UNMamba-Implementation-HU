# %%
import numpy as np

# %%
history = np.load("../unmixing_results.npz", allow_pickle=True)

# %%
history.keys()
# Out:
# KeysView(NpzFile '../unmixing_results.npz' with keys: epochs, losses, M_history, E_history, metrics)

# %%
history["losses"]
# Out:
# array([1.94108677, 1.75550079, 1.61127877, 1.53579533, 1.47151613,
#        1.40969825, 1.37781   , 1.34858584, 1.31992257, 1.30487287,
#        1.29090714, 1.27706647, 1.26973736, 1.26289606, 1.25608039,
#        1.25245571, 1.24906218, 1.24567223, 1.24386537, 1.24217129,
#        1.24047673, 1.23957264, 1.23872435, 1.23787522, 1.23742199,
#        1.23699665, 1.2365706 , 1.23634326, 1.23612976, 1.23591602,
#        1.23580205, 1.23569489, 1.23558772, 1.2355305 , 1.23547673,
#        1.23542297, 1.23539436, 1.23536754, 1.23534071, 1.23532641,
#        1.23531282, 1.23529935, 1.23529196, 1.23528504, 1.23527801,
#        1.23527408, 1.2352705 , 1.2352668 , 1.23526537, 1.23526394,
#        1.23526263, 1.23526227, 1.2352618 ])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history["epochs"], history["losses"])
plt.title("Loss vs Epochs")
plt.xlabel("Epochs")
plt.xlabel("Losses")
plt.show()

# %%
for i, map in enumerate(history["M_history"][-1:]):
    map = map.squeeze()
    plt.figure(figsize=(9, 9))
    
    for i in range(len(map)):
        plt.subplot(2, 2, i + 1)
        plt.imshow(map[i], cmap="jet")
    
    plt.savefig(f"../results/M{i}.png")

# %%
for i, endmems in enumerate(history["E_history"][-1:]):
    plt.figure(figsize=(18, 9))
    
    for i in range(len(map)):
        plt.subplot(2, 2, i + 1)
        plt.plot(endmems[i])
    
    plt.savefig(f"../results/E{i}.png")

# %%
metrics = history["metrics"].item()

# %%
for k, v in metrics.items():
    print(k, v)
# Out:
# rec_rmse 0.3168350225938206
# sad_per_em [1.33756351 1.40542062 1.07245806 1.11763671]
# mean_sad 1.2332697237678438
# sid_per_em [5.95515595 7.18948592 6.28661414 5.40003454]
# mean_sid 6.20782264038228
# ab_rmse_per_em [0.4193171  0.45640288 0.38286029 0.22766385]
# mean_ab_rmse 0.371561028195267
